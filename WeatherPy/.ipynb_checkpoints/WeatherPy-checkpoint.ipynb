# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observation 1: Southern Hemisphere climates tend to be slightly milder than those at similar latitudes in the Northern
# Hemisphere. This is because the Southern Hemisphere has significantly more ocean and much less land; water heats up
# and cools down more slowly than land.
# Observation 2: Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature
# drops. This happens as equatorial region receives sunlight straight with less or no angle due to the shape of earth.
# Observation 3: Latitude doesn't have a strong influence on wind speed. The speed of the wind is controlled by the
# strength of the air pressure gradient, the stronger the pressure gradient the higher the wind speed.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import csv
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import datetime
import scipy.stats as st
from scipy.stats import linregress
from citipy import citipy
from pprint import pprint
from api_keys import weather_api_key
from api_keys import g_key

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# # Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
            
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
    # Wait for 5 seconds
    if index_counter % 50 == 0:
        time.sleep(5)    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : salo
# Processing Record 2 of Set 1 : hobart
# Processing Record 3 of Set 1 : parrita
# Processing Record 4 of Set 1 : yarmouth
# Processing Record 5 of Set 1 : benguela
# Processing Record 6 of Set 1 : nikolskoye
# Processing Record 7 of Set 1 : east london
# Processing Record 8 of Set 1 : cape town
# Processing Record 9 of Set 1 : cabo san lucas
# Processing Record 10 of Set 1 : port hardy
# Processing Record 11 of Set 1 : celestun
# Processing Record 12 of Set 1 : goderich
# Processing Record 13 of Set 1 : jamestown
# Processing Record 14 of Set 1 : rikitea
# Processing Record 15 of Set 1 : hamilton
# Processing Record 16 of Set 1 : nichinan
# Processing Record 17 of Set 1 : palmas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 1 : horsham
# Processing Record 19 of Set 1 : kahului
# Processing Record 20 of Set 1 : airai
# City not found. Skipping...
# Processing Record 21 of Set 1 : mataura
# Processing Record 22 of Set 1 : ushuaia
# Processing Record 23 of Set 1 : arraial do cabo
# Processing Record 24 of Set 1 : nome
# Processing Record 25 of Set 1 : cap malheureux
# Processing Record 26 of Set 1 : albany
# Processing Record 27 of Set 1 : ritchie
# Processing Record 28 of Set 1 : jumla
# Processing Record 29 of Set 1 : adrano
# City not found. Skipping...
# Processing Record 30 of Set 1 : busselton
# Processing Record 31 of Set 1 : puerto ayora
# Processing Record 32 of Set 1 : labuhan
# City not found. Skipping...
# Processing Record 33 of Set 1 : leningradskiy
# Processing Record 34 of Set 1 : punta arenas
# Processing Record 35 of Set 1 : bubaque
# Processing Record 36 of Set 1 : leh
# Processing Record 37 of Set 1 : barrow
# Processing Record 38 of Set 1 : hilo
# Processing Record 39 of Set 1 : okhotsk
# Processing Record 40 of Set 1 : dicabisagan
# Processing Record 41 of Set 1 : kapaa
# Processing Record 42 of Set 1 : gondanglegi
# Processing Record 43 of Set 1 : tari
# City not found. Skipping...
# Processing Record 44 of Set 1 : varnavino
# City not found. Skipping...
# Processing Record 45 of Set 1 : port elizabeth
# Processing Record 46 of Set 1 : manaure
# Processing Record 47 of Set 1 : calama
# Processing Record 48 of Set 1 : khatanga
# Processing Record 49 of Set 1 : turka
# Processing Record 50 of Set 1 : coihaique
# Processing Record 0 of Set 2 : marawi
# Processing Record 1 of Set 2 : codrington
# Processing Record 2 of Set 2 : avarua
# Processing Record 3 of Set 2 : hermanus
# Processing Record 4 of Set 2 : benton
# Processing Record 5 of Set 2 : bathsheba
# Processing Record 6 of Set 2 : bilma
# Processing Record 7 of Set 2 : sola
# Processing Record 8 of Set 2 : faya
# Processing Record 9 of Set 2 : chuy
# Processing Record 10 of Set 2 : meulaboh
# Processing Record 11 of Set 2 : stuttgart
# Processing Record 12 of Set 2 : touros
# Processing Record 13 of Set 2 : belyy yar
# Processing Record 14 of Set 2 : grabs
# Processing Record 15 of Set 2 : atuona
# Processing Record 16 of Set 2 : mandera
# Processing Record 17 of Set 2 : bengkulu
# Processing Record 18 of Set 2 : margate
# Processing Record 19 of Set 2 : pemba
# Processing Record 20 of Set 2 : dunedin
# Processing Record 21 of Set 2 : hualmay
# Processing Record 22 of Set 2 : avera
# Processing Record 23 of Set 2 : oksfjord
# Processing Record 24 of Set 2 : santa isabel do rio negro
# Processing Record 25 of Set 2 : nouadhibou
# Processing Record 26 of Set 2 : krasni okny
# Processing Record 27 of Set 2 : provideniya
# Processing Record 28 of Set 2 : kamenka
# Processing Record 29 of Set 2 : mar del plata
# Processing Record 30 of Set 2 : bethel
# Processing Record 31 of Set 2 : hithadhoo
# Processing Record 32 of Set 2 : sitka
# Processing Record 33 of Set 2 : port macquarie
# Processing Record 34 of Set 2 : redmond
# Processing Record 35 of Set 2 : castelo branco
# Processing Record 36 of Set 2 : mugur-aksy
# Processing Record 37 of Set 2 : port alfred
# Processing Record 38 of Set 2 : georgetown
# Processing Record 39 of Set 2 : kavieng
# City not found. Skipping...
# Processing Record 40 of Set 2 : manga
# Processing Record 41 of Set 2 : kaitangata
# Processing Record 42 of Set 2 : butaritari
# Processing Record 43 of Set 2 : bredasdorp
# Processing Record 44 of Set 2 : qaanaaq
# Processing Record 45 of Set 2 : salalah
# Processing Record 46 of Set 2 : alice town
# Processing Record 47 of Set 2 : vaini
# Processing Record 48 of Set 2 : ikom
# Processing Record 49 of Set 2 : tadine
# Processing Record 50 of Set 2 : okha
# Processing Record 0 of Set 3 : new norfolk
# Processing Record 1 of Set 3 : kirakira
# Processing Record 2 of Set 3 : kupang
# Processing Record 24 of Set 4 : whitehorse
# Processing Record 25 of Set 4 : bapatla
# Processing Record 26 of Set 4 : tignere
# Processing Record 27 of Set 4 : yellowknife
# Processing Record 28 of Set 4 : san pedro
# Processing Record 29 of Set 4 : saskylakh
# Processing Record 30 of Set 4 : mount isa
# Processing Record 31 of Set 4 : san patricio
# Processing Record 32 of Set 4 : constitucion
# Processing Record 33 of Set 4 : mitsamiouli
# Processing Record 34 of Set 4 : matay
# Processing Record 35 of Set 4 : thompson
# Processing Record 36 of Set 4 : bambous virieux
# Processing Record 37 of Set 4 : xining
# Processing Record 38 of Set 4 : totma
# Processing Record 39 of Set 4 : lakes entrance
# Processing Record 40 of Set 4 : bluff
# Processing Record 41 of Set 4 : vojens
# Processing Record 42 of Set 4 : sao geraldo do araguaia
# Processing Record 43 of Set 4 : isangel
# Processing Record 44 of Set 4 : marathon
# Processing Record 45 of Set 4 : liverpool
# Processing Record 46 of Set 4 : sorong
# Processing Record 47 of Set 4 : freeport
# Processing Record 48 of Set 4 : kismayo
# Processing Record 49 of Set 4 : husavik
# Processing Record 50 of Set 4 : viseu
# City not found. Skipping...
# Processing Record 0 of Set 5 : gilgit
# Processing Record 1 of Set 5 : yumen
# City not found. Skipping...
# Processing Record 2 of Set 5 : savonlinna
# Processing Record 3 of Set 5 : aksarka
# City not found. Skipping...
# Processing Record 4 of Set 5 : hervey bay
# Processing Record 5 of Set 5 : la ronge
# Processing Record 6 of Set 5 : carora
# Processing Record 7 of Set 5 : wattegama
# Processing Record 8 of Set 5 : horodyshche
# Processing Record 9 of Set 5 : katherine
# Processing Record 10 of Set 5 : anuradhapura
# Processing Record 11 of Set 5 : guanare
# Processing Record 12 of Set 5 : tual
# Processing Record 13 of Set 5 : mount gambier
# Processing Record 14 of Set 5 : noumea
# Processing Record 15 of Set 5 : kutum
# Processing Record 16 of Set 5 : lianzhou
# Processing Record 17 of Set 5 : ouadda
# Processing Record 18 of Set 5 : custodia
# Processing Record 19 of Set 5 : northam
# City not found. Skipping...
# Processing Record 20 of Set 5 : carnarvon
# Processing Record 21 of Set 5 : kloulklubed
# Processing Record 22 of Set 5 : progreso
# Processing Record 23 of Set 5 : ancud
# Processing Record 24 of Set 5 : alta floresta
# City not found. Skipping...
# Processing Record 25 of Set 5 : ode
# Processing Record 26 of Set 5 : zonguldak
# Processing Record 27 of Set 5 : nawabganj
# Processing Record 28 of Set 5 : jalu
# Processing Record 29 of Set 5 : nouna
# Processing Record 30 of Set 5 : san carlos de bariloche
# Processing Record 31 of Set 5 : fortuna
# Processing Record 32 of Set 5 : luebo
# City not found. Skipping...
# Processing Record 33 of Set 5 : bairiki
# Processing Record 34 of Set 5 : sosnovo-ozerskoye
# Processing Record 35 of Set 5 : cuamba
# Processing Record 36 of Set 5 : san quintin
# Processing Record 37 of Set 5 : chokurdakh
# Processing Record 38 of Set 5 : tazovskiy
# Processing Record 39 of Set 5 : champerico
# Processing Record 40 of Set 5 : annau
# Processing Record 41 of Set 5 : tuatapere
# Processing Record 42 of Set 5 : kalakamati
# Processing Record 43 of Set 5 : ust-maya
# Processing Record 44 of Set 5 : itanhem
# Processing Record 45 of Set 5 : vestmannaeyjar
# Processing Record 46 of Set 5 : valdosta
# Processing Record 47 of Set 5 : poso
# Processing Record 48 of Set 5 : huicungo
# City not found. Skipping...
# Processing Record 49 of Set 5 : chapais
# Processing Record 50 of Set 5 : raudeberg
# Processing Record 0 of Set 6 : muros
# Processing Record 1 of Set 6 : yevsino
# Processing Record 2 of Set 6 : longyearbyen
# Processing Record 3 of Set 6 : severobaykalsk
# Processing Record 4 of Set 6 : riyadh
# Processing Record 5 of Set 6 : dese
# Processing Record 6 of Set 6 : awjilah
# Processing Record 7 of Set 6 : mayumba
# City not found. Skipping...
# Processing Record 8 of Set 6 : pangnirtung
# Processing Record 9 of Set 6 : kamenskiy
# Processing Record 10 of Set 6 : nacala
# Processing Record 11 of Set 6 : osterhofen
# Processing Record 12 of Set 6 : juegang
# Processing Record 13 of Set 6 : chapleau
# Processing Record 14 of Set 6 : logrono
# Processing Record 15 of Set 6 : saint george
# Processing Record 16 of Set 6 : erenhot
# Processing Record 17 of Set 6 : los llanos de aridane
# Processing Record 18 of Set 6 : salta
# Processing Record 19 of Set 6 : izvestkovyy
# Processing Record 20 of Set 6 : porto novo
# Processing Record 21 of Set 6 : jiayuguan
# Processing Record 22 of Set 6 : jishou
# Processing Record 23 of Set 6 : hasaki
# Processing Record 24 of Set 6 : zaozerne
# Processing Record 25 of Set 6 : ormara
# Processing Record 26 of Set 6 : uyar
# Processing Record 27 of Set 6 : necochea
# Processing Record 28 of Set 6 : bahar
# Processing Record 29 of Set 6 : port augusta
# Processing Record 30 of Set 6 : sibu
# Processing Record 31 of Set 6 : rodino
# Processing Record 32 of Set 6 : victoria
# Processing Record 33 of Set 6 : abu samrah
# City not found. Skipping...
# Processing Record 34 of Set 6 : kilindoni
# Processing Record 35 of Set 6 : casa grande
# Processing Record 36 of Set 6 : henties bay
# Processing Record 37 of Set 6 : sobolevo
# Processing Record 38 of Set 6 : lebu
# Processing Record 39 of Set 6 : arman
# Processing Record 40 of Set 6 : liepaja
# Processing Record 41 of Set 6 : flinders
# Processing Record 42 of Set 6 : jacqueville
# Processing Record 43 of Set 6 : casablanca
# City not found. Skipping...
# Processing Record 44 of Set 6 : talnakh
# Processing Record 45 of Set 6 : grand gaube
# Processing Record 46 of Set 6 : havre-saint-pierre
# Processing Record 47 of Set 6 : chepareria
# Processing Record 48 of Set 6 : mumford
# Processing Record 49 of Set 6 : mao
# Processing Record 50 of Set 6 : thinadhoo
# Processing Record 0 of Set 7 : kudahuvadhoo
# Processing Record 1 of Set 7 : arteaga
# Processing Record 2 of Set 7 : dinguiraye
# City not found. Skipping...
# Processing Record 3 of Set 7 : chiredzi
# Processing Record 4 of Set 7 : carutapera
# Processing Record 5 of Set 7 : diffa
# Processing Record 6 of Set 7 : payo
# Processing Record 7 of Set 7 : kastamonu
# Processing Record 8 of Set 7 : umm bab
# Processing Record 9 of Set 7 : rio grande
# Processing Record 10 of Set 7 : remanso
# Processing Record 11 of Set 7 : praya
# Processing Record 12 of Set 7 : gusinoye ozero
# Processing Record 13 of Set 7 : binga
# Processing Record 14 of Set 7 : vardo
# Processing Record 30 of Set 11 : asamankese
# Processing Record 31 of Set 11 : mayo
# Processing Record 32 of Set 11 : rio gallegos
# Processing Record 33 of Set 11 : gazli
# Processing Record 34 of Set 11 : panguna
# Processing Record 35 of Set 11 : kawalu
# Processing Record 36 of Set 11 : qui nhon
# Processing Record 37 of Set 11 : murgab
# Processing Record 38 of Set 11 : huarmey
# City not found. Skipping...
# Processing Record 39 of Set 11 : namatanai
# Processing Record 40 of Set 11 : pacific grove
# Processing Record 41 of Set 11 : horizontina
# Processing Record 42 of Set 11 : yen bai
# Processing Record 43 of Set 11 : gobabis
# Processing Record 44 of Set 11 : zeya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({"City":city_name_list,
                             "Lat":lat_list,
                             "Lng":lng_list,
                             "Max Temp":max_temp_list,
                             "Humidity":humidity_list,
                             "Cloudiness":cloudiness_list,
                             "Wind Speed":wind_speed_list,
                             "Country":country_list,
                             "Date":date_list})    
weather_dict.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Salò  45.61   10.53     73.40        53          40        5.82
# 1    Hobart -42.88  147.33     46.40        70          40       10.29
# 2   Parrita   9.52  -84.32     68.00        77          99        8.05
# 3  Yarmouth  41.71  -70.23     62.01        54           1        8.05
# 4  Benguela -12.58   13.41     77.58        65          23       10.27
#
#   Country        Date
# 0      IT  1600866735
# 1      AU  1600866439
# 2      CR  1600866735
# 3      US  1600866735
# 4      AO  1600866735

# %%
# Save city data into a csv file
weather_dict.to_csv("cities.csv", encoding='utf-8', index = False)

# %% [markdown]
# # Latitude vs. Temperature Plot

# %% [markdown]
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (04/01/20)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# Highest temperature is found close to 40 latitude and as the latidude increases or decreases, temperature drops.

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (04/01/20)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# Polar regions have lower humidity and as latitude gets higher,humidity gets higher in southern hemisphere.

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (04/01/20)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# The data for cloudiness is spread across the latitude

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (04/01/20)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# Wind speed data is widely spread across the latitude

# %% [markdown]
# # Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Define function for creating linear regression and scatter plot
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call a function #2
annotate(equation, 10, 20)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.81

# %% [markdown]
# There is a strong negative correlation between latitude and max temperature for northern hemisphere.

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call a function #2
annotate(equation, -25, 45)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.74

# %% [markdown]
# There is a positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 12)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.04

# %% [markdown]
# There is low positive correlation between latitude and humidity for northern hemisphere

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call a function #2
annotate(equation, -50, 10)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.08

# %% [markdown]
# There is a low positive correlation between latitude and humidity for southern hemisphere.

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call a function #2
annotate(equation, 30, 60)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.02

# %% [markdown]
# There is a very low negative correlation between latitude and cloudiness for Northern hemisphere.

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call a function #2
annotate(equation, -50, 56)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# There is a low positive correlation between latitude and cloudiness for Southern hemisphere.

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call a function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call a function #2
annotate(equation, 20, 27)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.11

# %% [markdown]
# There is a weak positive correlation between latitude and windspeed for Northern hemisphere.

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression¶

# %%
# Call a function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call a function #2
annotate(equation, -30, 30)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.01

# %% [markdown]
# There is a weak negative correlation between latitude and wind speed for Southern hemisphere.
